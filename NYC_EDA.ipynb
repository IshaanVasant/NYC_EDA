# %% [markdown]
# # Data Science Assignment - Ishaan Vasant

# %% [markdown]
# ## NYC DOB Permit Issuance - Exploratory Data Analysis

# %% [markdown]
# ### Importing Dependencies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display

# %% [markdown]
# ### Changing Directory

# %%
cd
# Out:
# /Users/ishaan

# %%
cd Downloads
# Out:
# /Users/ishaan/Downloads

# %% [markdown]
# ### Reading and Displaying NYC DOB Permit Issuance Dataset

# %%
df = pd.read_csv('DOB_Permit_Issuance.csv')

# %%
pd.options.display.max_columns = None
display(df)
# Out:
#                BOROUGH    Bin # House #             Street Name      Job #  \
# 0                BRONX  2102476     200          E 135TH STREET  240249842
# 1            MANHATTAN  1090833     249          WEST 14 STREET  140818435
# 2            MANHATTAN  1015903      20        WEST 36TH STREET  123372466
# 3               QUEENS  4467709   14-30                BROADWAY  421105618
# 4               QUEENS  4048873   42-06              108 STREET  421024689
# 5                BRONX  2085547     285            W 261 STREET  220690786
# 6               QUEENS  4094152   87-03              81ST  ROAD  421671097
# 7            MANHATTAN  1058592    2288   FREDRICK DOUGLAS BLVD  123510487
# 8               QUEENS  4617617     157         BEACH 96 STREET  421360084
# 9             BROOKLYN  3006277      58       SAINT MARKS PLACE  321916414
# 10       STATEN ISLAND  5146639    1200              MANOR ROAD  500870505
# ...

# %% [markdown]
# ### Data Insights

# %%
df.shape
# Out:
# (3508249, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3508249 entries, 0 to 3508248
# Data columns (total 60 columns):
# BOROUGH                             object
# Bin #                               object
# House #                             object
# Street Name                         object
# Job #                               int64
# Job doc. #                          int64
# Job Type                            object
# Self_Cert                           object
# Block                               object
# Lot                                 object
# Community Board                     object
# Zip Code                            float64
# Bldg Type                           float64
# Residential                         object
# Special District 1                  object
# Special District 2                  object
# Work Type                           object
# Permit Status                       object
# Filing Status                       object
# ...

# %% [markdown]
# #### • Data has over 3.5 million entries and 60 features
# #### • Data types vary from int and float to a range of objects

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Boroughs

# %%
df['BOROUGH'].value_counts()
# Out:
# MANHATTAN        1462213
# BROOKLYN          813934
# QUEENS            731242
# BRONX             296495
# STATEN ISLAND     204365
# Name: BOROUGH, dtype: int64

# %%
values = df['BOROUGH'].value_counts().keys().tolist()
counts = df['BOROUGH'].value_counts().tolist()
plt.figure(figsize=(10,5))
plt.bar(values,counts,color='b',alpha=0.65)
plt.grid(axis='x', alpha=0)
plt.xlabel('Borough')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# #### • Most of the construction permits apply to the borough of Manhattan with Staten Island gathering the least

# %% [markdown]
# #### Job Document Number

# %%
df['Job doc. #'].value_counts()
# Out:
# 1     3189810
# 2      249293
# 3       55988
# 4        9471
# 5        2499
# 6         736
# 7         298
# 8         106
# 9          39
# 10          5
# 12          2
# 11          2
# Name: Job doc. #, dtype: int64

# %%
values = df['Job doc. #'].value_counts().keys().tolist()
counts = df['Job doc. #'].value_counts().tolist()
plt.figure(figsize=(10,10))
plt.bar(values,counts,color='b',alpha=0.65)
plt.grid(axis='x', alpha=0)
plt.xlabel('Job doc. #')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# #### • Only Job Doc. # 1, 2 and 3 are significant with 1 gathering over 3 million permits

# %% [markdown]
# #### Job Type

# %%
df['Job Type'].value_counts()
# Out:
# A2    2094465
# NB     491768
# A3     384782
# A1     371457
# DM      90049
# SG      75728
# Name: Job Type, dtype: int64

# %%
values = df['Job Type'].value_counts().keys().tolist()
counts = df['Job Type'].value_counts().tolist()
plt.figure(figsize=(10,5))
plt.bar(values,counts,color='b',alpha=0.65)
plt.grid(axis='x', alpha=0)
plt.xlabel('Job Type')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# #### Data from the DOB Job Application Filings dataset was collected and it revealed what the above acronyms stand for: -
#
# • A1 = Alteration Type I, A major alteration that will change the use, egress, or occupancy of the building.
#
# • A2 = Alteration Type II, An application with multiple types of work that do not affect the use, egress, or occupancy of the building.
#
# • A3 = Alteration Type III, One type of minor work that doesn't affect the use, egress, or occupancy of the building.
#
# • NB = New Building, An application to build a new structure. “NB” cannot be selected if any existing building elements are to remain—for example a part of an old foundation, a portion of a façade that will be incorporated into the construction, etc.
#
# • DM = Demolition, An application to fully or partially demolish an existing building.
#
# #### • It is seen that most permits were given to the A2 Job Type

# %% [markdown]
# #### Work Type

# %%
df['Work Type'].value_counts()
# Out:
# OT    986608
# PL    704541
# EQ    541170
# MH    317608
# SP    125786
# BL     68916
# FP     62084
# FB     38900
# FS     22558
# SD     18775
# CC     11341
# FA       244
# NB         1
# Name: Work Type, dtype: int64

# %%
values = df['Work Type'].value_counts().keys().tolist()
counts = df['Work Type'].value_counts().tolist()
plt.figure(figsize=(10,8))
plt.bar(values,counts,color='b',alpha=0.65)
plt.grid(axis='x', alpha=0)
plt.xlabel('Work Type')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# #### Data from the NYC buildings website was collected and it revealed what the above acronyms stand for: -
#
# BL:	Boiler
#
# CC:	Curb Cut
#
# CH:	Chute
#
# DM:	Demolition and Removal
#
# EQ:	Construction Equipment
#
# EW:	Equipment Work
#
# FA:	Fire Alarm
#
# FB:	Fuel Burning
#
# FN:	Fence
#
# FP:	Fire Suppression
#
# FS:	Fuel Storage
#
# MH:	Mechanical/HVAC
#
# OT:	Other
#
# PL:	Plumbing
#
# SD:	Standpipe
#
# SF:	Scaffold
#
# SG:	Sign
#
# SP:	Sprinkler
#
# #### • It is seen that most permits were given to the 'Other' category of work types and the second most were given to Plumbing work

# %% [markdown]
# #### Building Type

# %%
df['Bldg Type'].value_counts()
# Out:
# 2.0    2619873
# 1.0     833899
# Name: Bldg Type, dtype: int64

# %%
values = df['Bldg Type'].value_counts().keys().tolist()
counts = df['Bldg Type'].value_counts().tolist()
plt.figure(figsize=(5,5))
plt.bar(values,counts,color='b',alpha=0.65)
plt.grid(axis='x', alpha=0)
plt.xlabel('Bldg Type')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# #### • 2.6 million permits were given for 2-person occupancy type buildings and less than a million permits were given to single-person occupancy type buildings

# %% [markdown]
# #### Permit Type

# %%
df['Permit Type'].value_counts()
# Out:
# EW    1551850
# PL     704540
# EQ     541170
# AL     312159
# NB     227844
# SG      75708
# DM      50386
# FO      44591
# Name: Permit Type, dtype: int64

# %%
values = df['Permit Type'].value_counts().keys().tolist()
counts = df['Permit Type'].value_counts().tolist()
plt.figure(figsize=(10,8))
plt.bar(values,counts,color='b',alpha=0.65)
plt.grid(axis='x', alpha=0)
plt.xlabel('Permit Type')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# #### Data from the NYC buildings website was collected and it revealed what the above acronyms stand for: -
#
# AL:	Architectural
#
# EW:	Equipment Work
#
# EQ: Construction Equipment
#
# FO:	Foundation
#
# NB:	New Building
#
# PL:	Plumbing
#
# SG: Sign
#
# DM: Demolition and Removal
#
# #### • It is seen that most permits types were of the Equipment work category and the second most were of the Plumbing category

# %% [markdown]
# #### Owner's Business Type

# %%
df["Owner's Business Type"].value_counts()
# Out:
# CORPORATION           1130020
# INDIVIDUAL            1106781
# PARTNERSHIP            769321
# OTHER                  155929
# CONDO/CO-OP             87028
# OTHER GOV'T AGENCY      55623
# NYCHA                   11523
# NYCHA/HHC                9118
# HPD                      6865
# NYC AGENCY               6849
# HHC                      1277
# DCAS                     1199
# NY STATE                 1178
# DOE                       950
# Name: Owner's Business Type, dtype: int64

# %%
values = df["Owner's Business Type"].value_counts().keys().tolist()
counts = df["Owner's Business Type"].value_counts().tolist()
plt.figure(figsize=(26,10))
plt.bar(values,counts,color='b',alpha=0.65)
plt.grid(axis='x', alpha=0)
plt.xlabel("Owner's Business Type")
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# #### • Around 1.1 million permits were for buildings whose owner's business type was either 'Individual' or 'Corporation' with 'Partnership' gaining close to 800,000 permits

# %% [markdown]
# #### Filing Status

# %%
df['Filing Status'].value_counts()
# Out:
# INITIAL    2559794
# RENEWAL     948455
# Name: Filing Status, dtype: int64

# %%
values = df['Filing Status'].value_counts().keys().tolist()
counts = df['Filing Status'].value_counts().tolist()
plt.bar(values,counts,color='b',alpha=0.65)
plt.grid(axis='x', alpha=0)
plt.xlabel('Filing Status')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# #### • Over 2.5 million permits were Initial permits and just under 1 million permits were renewals

# %% [markdown]
# ### Correlation

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),cmap='Blues',annot=True)

# %% [markdown]
# #### • The first digit of the Job Numbers are assigned based on which borough it represents: -
# • 1 = Manhattan
#
# • 2 = Bronx
#
# • 3 = Brooklyn
#
# • 4 = Queens
#
# • 5 = Staten Island
#
# #### Therefore, it makes perfect sense that the correlation heatmap shows a positive correlation between the Job # and geographical features such as Zip Code and Council_District (council district for the building's address, geocoded based on address)

# %% [markdown]
# ### Issuance Date
#
# #### The number of permit issuances for each year from 1989 to 2019 (until March) were computed and plotted below

# %%
df1=df['Issuance Date']
df2=df1[df1.notnull()]
df3=pd.DatetimeIndex(df2).year

# %%
plt.figure(figsize=(15,8))
sns.set(style="white")
sns.distplot(df3,bins=31,kde=False,hist_kws={"histtype": "bar", "rwidth": 0.4,"alpha": 0.55, "color": "b"})

# %% [markdown]
# #### • It is seen that the number of construction permits issued have been increasing steadily over the past 30 years. 2008 and 2009 saw a decrease in the number of construction permits issued and that could be a side effect of The Great Recession - the financial crisis that hit the world economy in 2008.
#
#
# #### • The number of issuances for the year 2019 was projected below based on the current rate :-

# %%
a=38070*3
b=np.arange(1,a)
c=(b*2019)/b
df4=df3.values
df5=np.append(df4,c)

# %%
sns.set(style="white")
fig, ax = plt.subplots(figsize=(15,8))
sns.distplot(df5,bins=31,ax=ax,kde=False,hist_kws={"histtype": "bar", "rwidth": 0.4,"alpha": 0.45, "color": "y"})
sns.distplot(df3,bins=31,ax=ax,kde=False,hist_kws={"histtype": "bar", "rwidth": 0.4,"alpha": 0.55, "color": "b"})

# %% [markdown]
# #### • It is seen that the decline seen in 2008 and 2009 seems to be repeating itself, thus drawing the possible conclusion that we may be heading into another era of financial crisis.

# %% [markdown]
# #### • The NYChist dataset was observed which provides the number of people emplyed (annually) in various industries from the year 1990 to the year 2018. The data about the employees from the "Construction of Buildings" category were extracted and the trend was plotted.

# %%
df6 = pd.read_excel('NYChist.xls')
df6
# Out:
#        AREA  YEAR  SERIESCODE       AREANAME  \
# 0     93561  2019           0  New York City
# 1     93561  2019     5000000  New York City
# 2     93561  2019     6000000  New York City
# 3     93561  2019     7000000  New York City
# 4     93561  2019     8000000  New York City
# 5     93561  2019    15000000  New York City
# 6     93561  2019    20236000  New York City
# 7     93561  2019    20238000  New York City
# 8     93561  2019    20238200  New York City
# 9     93561  2019    20238300  New York City
# 10    93561  2019    30000000  New York City
# 11    93561  2019    31000000  New York City
# 12    93561  2019    32000000  New York City
# 13    93561  2019    32315000  New York City
# 14    93561  2019    40000000  New York City
# 15    93561  2019    41000000  New York City
# 16    93561  2019    41423000  New York City
# 17    93561  2019    41424000  New York City
# 18    93561  2019    41424300  New York City
# 19    93561  2019    41424400  New York City
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3557 entries, 0 to 3556
# Data columns (total 46 columns):
# AREA              3557 non-null int64
# YEAR              3557 non-null int64
# SERIESCODE        3557 non-null int64
# AREANAME          3557 non-null object
# INDUSTRY_TITLE    3557 non-null object
# JAN               3557 non-null float64
# FEB               3557 non-null float64
# MAR               3433 non-null float64
# APR               3433 non-null float64
# MAY               3433 non-null float64
# JUN               3433 non-null float64
# JUL               3433 non-null float64
# AUG               3433 non-null float64
# SEP               3433 non-null float64
# OCT               3433 non-null float64
# NOV               3433 non-null float64
# DEC               3433 non-null float64
# ANNUAL            3433 non-null float64
# Unnamed: 18       0 non-null float64
# JAN.1             1358 non-null float64
# FEB.1             1234 non-null float64
# ...

# %%
df7=df6[df6['INDUSTRY_TITLE']=='Construction of Buildings']
df7
# Out:
#        AREA  YEAR  SERIESCODE       AREANAME             INDUSTRY_TITLE   JAN  \
# 6     93561  2019    20236000  New York City  Construction of Buildings  48.0
# 130   93561  2018    20236000  New York City  Construction of Buildings  45.3
# 254   93561  2017    20236000  New York City  Construction of Buildings  43.5
# 378   93561  2016    20236000  New York City  Construction of Buildings  41.3
# 502   93561  2015    20236000  New York City  Construction of Buildings  36.7
# 626   93561  2014    20236000  New York City  Construction of Buildings  32.8
# 750   93561  2013    20236000  New York City  Construction of Buildings  31.0
# 874   93561  2012    20236000  New York City  Construction of Buildings  29.8
# 998   93561  2011    20236000  New York City  Construction of Buildings  28.1
# 1122  93561  2010    20236000  New York City  Construction of Buildings  29.4
# 1246  93561  2009    20236000  New York City  Construction of Buildings  32.9
# ...

# %%
plt.plot(df7['YEAR'],df7['ANNUAL'],color='r')

# %%
values = df3.value_counts().keys().tolist()
counts = df3.value_counts().tolist()

# %%
v=np.array(values)
c=np.array(counts)
df8=np.column_stack((v,c))

df9=sorted(df8,key=lambda x: x[0])
val, count = zip(*df9)

# %%
plt.plot(val,count,color='b')

# %%
fig, ax1 = plt.subplots(figsize=(15,8))

ax2 = ax1.twinx()
ax2.plot(df7['YEAR'],df7['ANNUAL'], 'r-')
ax1.plot(val, count, 'b-')

ax1.set_xlabel('Year')
ax2.set_ylabel('Number of Construction Employees', color='r')
ax1.set_ylabel('Number of Construction Issuances', color='b')

plt.show()

# %% [markdown]
# #### • The trend of the number of construction employees is very similar to the trend of the number of permit issuances and again, that makes perfect sense. A key area to notice again is the 2008-2009 timeline where both graphs go through a steep depression. This confirms the direct correlation and impact of the financial crisis on the number of permits being issued and therfore on the number of construction workers being employed.
